# %%
pip install folium
# Out:
# ...
#                                               0.0/97.0 kB ? eta -:--:--
#      ------------                             30.7/97.0 kB ? eta -:--:--
#      ------------                             30.7/97.0 kB ? eta -:--:--
#      -------------------------------------- 97.0/97.0 kB 923.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
import pandas as pd

file_path = "D:\\Course\\Data science\\IBM\\historical_automobile_sales.csv"
df = pd.read_csv(file_path)

print('Data read into a dataframe!')
# Out:
# Data read into a dataframe!

# %%
import pandas as pd

file_path = "D:\\Course\\Data science\\IBM\\historical_automobile_sales.csv"
df = pd.read_csv(file_path)

print('Data read into a dataframe!')
# Out:
# Data read into a dataframe!

# %%
df.describe()
# Out:
#               Year   Recession  Consumer_Confidence  Seasonality_Weight  \
# count   528.000000  528.000000           528.000000          528.000000
# mean   2001.500000    0.214015           101.140170            0.575795
# std      12.710467    0.410526            10.601154            0.454477
# min    1980.000000    0.000000            73.900000            0.000000
# 25%    1990.750000    0.000000            94.035000            0.250000
# 50%    2001.500000    0.000000           100.740000            0.500000
# 75%    2012.250000    0.000000           108.240000            0.750000
# max    2023.000000    1.000000           131.670000            1.500000
#
#               Price  Advertising_Expenditure  Competition         GDP  \
# count    528.000000               528.000000   528.000000  528.000000
# mean   24964.991956              3067.456439     6.064394   40.073903
# std     4888.073433              1139.564637     1.968350   16.249714
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Month', 'Recession', 'Consumer_Confidence',
#        'Seasonality_Weight', 'Price', 'Advertising_Expenditure', 'Competition',
#        'GDP', 'Growth_Rate', 'unemployment_rate', 'Automobile_Sales',
#        'Vehicle_Type', 'City'],
#       dtype='object')

# %%
# Create data for plotting
df_line = df.groupby(df['Year'])['Automobile_Sales'].mean()

# Create figure
plt.figure(figsize=(10, 6))
df_line.plot(kind='line')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Average Automobile Sales')
plt.title('Fluctuation of Automobile Sales Over Years')

# Display the line chart
plt.show()

# %% [markdown]
# # TASK 1.1: Develop a *Line chart* using the functionality of pandas to show how automobile sales fluctuate from year to year

# %%
plt.figure(figsize=(10, 6))

# Assuming your DataFrame is named 'df' and contains columns as specified
# If your data has a different structure, adjust the column names accordingly.

# Create data for plotting
df_line = df.groupby(df['Year'])['Automobile_Sales'].mean()
df_line.plot(kind='line')

# Adding ticks on x-axis for all years
plt.xticks(list(range(1980, 2024)), rotation=75)

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Average Automobile Sales')
plt.title('Automobile Sales during Recession')

# Adding annotations for at least two years of recession
plt.text(1982, 650, '1981-82 Recession', bbox=dict(facecolor='red', alpha=0.5))
# Add another annotation for the second year of recession
plt.text(2008, 1100, '2007-09 Recession', bbox=dict(facecolor='red', alpha=0.5))
# Add another annotation for the second year of recession
plt.text(1991, 800, '1991 Recession', bbox=dict(facecolor='red', alpha=0.5))
# Add another annotation for the second year of recession
plt.text(2000, 550, '2000-01 Recession', bbox=dict(facecolor='red', alpha=0.5))

# Add another annotation for the second year of recession
plt.text(2020, 550, '2020 Recession', bbox=dict(facecolor='red', alpha=0.5))

# Show legend if applicable
plt.legend()

# Display the line chart
plt.show()

# %% [markdown]
# # TASK 1.2: Plot different lines for categories of vehicle type and analyse the trend to answer the question Is there a noticeable difference in sales trends between different vehicle types during recession periods?

# %%
df_Mline = df.groupby(['Year', 'Vehicle_Type'], as_index=False)['Automobile_Sales'].sum()
df_Mline.set_index('Year', inplace=True)
df_Mline = df_Mline.groupby(['Vehicle_Type'])['Automobile_Sales']

plt.figure(figsize=(12, 8))
df_Mline.plot(kind='line')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Total Automobile Sales')
plt.title('Sales Trend Vehicle-wise during Recession')

# Show legend
plt.legend()

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Group by 'Recession' and calculate the average 'Automobile_Sales'
new_df = df.groupby('Recession')['Automobile_Sales'].mean().reset_index()

# Create the bar chart using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Recession', y='Automobile_Sales', hue='Recession', data=new_df)

# Adding labels and title
plt.xlabel('Period')
plt.ylabel('Average Automobile Sales')
plt.title('Average Automobile Sales during Recession and Non-Recession')
plt.xticks(ticks=[0, 1], labels=['Non-Recession', 'Recession'])

# Display the plot
plt.show()

# %% [markdown]
# # Use sub plotting to compare the variations in GDP during recession and non-recession period by developing line plots for each period.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Create dataframes for recession and non-recession period
rec_data = df[df['Recession'] == 1]
non_rec_data = df[df['Recession'] == 0]

# Figure
fig = plt.figure(figsize=(12, 6))

# Create different axes for subplotting
ax0 = fig.add_subplot(1, 2, 1)  # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2)  # add subplot 2 (1 row, 2 columns, second plot)

# Plot for recession period
sns.lineplot(x='Year', y='GDP', data=rec_data, label='Recession', ax=ax0)
ax0.set_xlabel('Year')
ax0.set_ylabel('GDP')
ax0.set_title('GDP Variation during Recession Period')

# Plot for non-recession period
sns.lineplot(x='Year', y='GDP', data=non_rec_data, label='Non-Recession', ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('GDP')
ax1.set_title('GDP Variation during Non-Recession Period')

plt.tight_layout()
plt.show()

# %% [markdown]
# # ASK 1.5: Develop a Bubble plot for displaying the impact of seasonality on Automobile Sales.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Filter data for non-recession years
non_rec_data = df[df['Recession'] == 0]

# Set size for bubble effect based on Seasonality Weight
size = non_rec_data['Seasonality_Weight'] 

# Create Bubble plot using scatter()
sns.scatterplot(data=non_rec_data, x='Month', y='Automobile_Sales', size=size, hue='Seasonality_Weight', legend=False)

# Adding labels and title
plt.xlabel('Month')
plt.ylabel('Automobile Sales')
plt.title('Seasonality Impact on Automobile Sales')

# Display the Bubble plot
plt.show()

# %% [markdown]
# # TASK 1.6: Use the functionality of Matplotlib to develop a scatter plot to identify the correlation between average vehicle price relate to the sales volume during recessions.

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Create a dataframe for recession period
rec_data = df[df['Recession'] == 1]

# Scatter plot for Consumer Confidence and Automobile Sales during recession
plt.scatter(rec_data['Consumer_Confidence'], rec_data['Automobile_Sales'])

# Adding labels and title
plt.xlabel('Consumer Confidence')
plt.ylabel('Automobile Sales')
plt.title('Consumer Confidence and Automobile Sales during Recessions')

# Display the scatter plot
plt.show()

# %% [markdown]
# # How does the average vehicle price relate to the sales volume during recessions?
#
# Plot another scatter plot and title it as 'Relationship between Average Vehicle Price and Sales during Recessions'

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Create a dataframe for recession period
rec_data = df[df['Recession'] == 1]

# Scatter plot for Average Vehicle Price and Automobile Sales during recession
plt.scatter(rec_data['Price'], rec_data['Automobile_Sales'])

# Adding labels and title
plt.xlabel('Average Vehicle Price')
plt.ylabel('Automobile Sales')
plt.title('Relationship between Average Vehicle Price and Sales during Recessions')

# Display the scatter plot
plt.show()

# %% [markdown]
# # TASK 1.7: Create a pie chart to display the portion of advertising expenditure of XYZAutomotives during recession and non-recession periods

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Filter the data for recession and non-recession periods
Rdata = df[df['Recession'] == 1]
NRdata = df[df['Recession'] == 0]

# Calculate the total advertising expenditure for both periods
RAtotal = Rdata['Advertising_Expenditure'].sum()
NRAtotal = NRdata['Advertising_Expenditure'].sum()

# Create a pie chart for the advertising expenditure
plt.figure(figsize=(8, 6))

labels = ['Recession', 'Non-Recession']
sizes = [RAtotal, NRAtotal]
percentages = [RAtotal / (RAtotal + NRAtotal) * 100, NRAtotal / (RAtotal + NRAtotal) * 100]

plt.pie(sizes, labels=[f'{label} ({size:,.2f} million)' for label, size in zip(labels, sizes)], autopct=lambda p: f'{p:.1f}% ({sizes[int(p/100.0 * len(sizes))]:,.2f} million)', startangle=90)

# Adding title
plt.title('Advertising Expenditure during Recession and Non-Recession Periods')

# Display the pie chart
plt.show()

# %% [markdown]
# # TASK 1.8: Develop a pie chart to display the total Advertisement expenditure for each vehicle type during recession period.

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Filter the data for recession periods
Rdata = df[df['Recession'] == 1]

# Calculate the total advertisement expenditure by vehicle type during recessions
VTsales = Rdata.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()

# Create a pie chart for the share of each vehicle type in total sales during recessions
plt.figure(figsize=(8, 8))

labels = VTsales.index
sizes = VTsales.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Adding title
plt.title('Share of Each Vehicle Type in Total Sales during Recessions')

# Display the pie chart
plt.show()

# %% [markdown]
# # TASK 1.9: Develop a lineplot to analyse the effect of the unemployment rate on vehicle type and sales during the Recession Period.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# If your data has a different structure, adjust the column names accordingly.

# Filter out the data for the recession period
df_rec = df[df['Recession'] == 1]

# Replace 'Actual_Unemployment_Column' with the correct column name for the unemployment rate
x_column = 'unemployment_rate'  # Replace with the actual column name
y_column = 'Automobile_Sales'   # Replace with the actual column name

# Create a line plot to analyze the effect of the unemployment rate on vehicle type and sales during the Recession Period
plt.figure(figsize=(12, 8))
sns.lineplot(data=df_rec, x=x_column, y=y_column,
             hue='Vehicle_Type', style='Vehicle_Type', markers='o', err_style=None)
plt.ylim(0, 850)  # Adjust the y-axis limits as needed
plt.legend(loc=(0.05, 0.3))

# Adding labels and title
plt.xlabel('Unemployment Rate')
plt.ylabel('Automobile Sales')
plt.title('Effect of Unemployment Rate on Vehicle Type and Sales during Recession')

# Display the line plot
plt.show()
# Out:
# C:\Users\Lokeshwaran\AppData\Local\Temp\ipykernel_2892\649703580.py:16: UserWarning:
# The markers list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=df_rec, x=x_column, y=y_column,

# %% [markdown]
# # OPTIONAL : TASK 1.10 Create a map on the hightest sales region/offices of the company during recession period

# %%
pip install pyodide
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pyodide
#   Using cached pyodide-0.0.2.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\Lokeshwaran\AppData\Local\Temp\pip-install-ti6o9z4p\pyodide_b5dda93392dd4a39a8fcc7fd26d0165a\setup.py", line 7, in <module>
#       raise ValueError(
#   ValueError: Pyodide is a Python distribution that runs in the browser or Node.js. It cannot be installed from PyPi.
#               See https://github.com/pyodide/pyodide for how to use Pyodide.
#   [end of output]
#
# ...

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

path = 'D:\\Course\\Data science\\IBM\\historical_automobile_sales.csv'
await download(path, "us-states.json")

filename = "us-states.json"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 from pyodide.http import pyfetch
#       3 async def download(url, filename):
#       4     response = await pyfetch(url)
#
# ModuleNotFoundError: No module named 'pyodide'

# %%
pip install dash
# Out:
# ...
#
#   Using cached dash-2.14.2-py3-none-any.whl (10.2 MB)
# ...
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# ...
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# ...
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# ...
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# ...
#   Using cached ansi2html-1.9.1-py3-none-any.whl (17 kB)
# ...

# %% [markdown]
# # PROJECT 2

# %% [markdown]
# ### TASK 1.1

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Uncomment this line and replace the file path with your CSV file
your_dataframe = pd.read_csv('D:\\Course\\Data science\\IBM\\historical_automobile_sales.csv')

# Assuming 'Date' and 'Year' are the columns you want to use for dropdowns
report_types = your_dataframe['Vehicle_Type'].unique()
years = your_dataframe['Year'].unique()

app.layout = html.Div([
    html.H1("Automobile Sales Statistics Dashboard", style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    html.Div([
        html.Label("Select Vehicle Type"),
        dcc.Dropdown(
            id='vehicle-type-dropdown',
            options=[{'label': vehicle_type, 'value': vehicle_type} for vehicle_type in report_types],
            value=report_types[0]
        ),
    ], style={'margin-bottom': '20px'}),

    html.Div([
        html.Label("Select Year"),
        dcc.Dropdown(
            id='year-dropdown',
            disabled=True
        ),
    ], style={'margin-bottom': '20px'}),

    html.Div([
        html.H2("Graphs Layout"),
        dcc.Graph(id='sample-graph')  # Include a simple graph component for testing
    ]),

])

@app.callback(
    Output('year-dropdown', 'options'),
    [Input('vehicle-type-dropdown', 'value')]
)
def update_year_dropdown(vehicle_type):
    if vehicle_type:
        available_years = your_dataframe[your_dataframe['Vehicle_Type'] == vehicle_type]['Year'].unique()
        return [{'label': year, 'value': year} for year in available_years]
    else:
        return []

@app.callback(
    Output('year-dropdown', 'disabled'),
    [Input('vehicle-type-dropdown', 'value')]
)
def update_year_dropdown_disable(vehicle_type):
    return not bool(vehicle_type)

@app.callback(
    Output('sample-graph', 'figure'),  # Update the 'figure' property of the graph component
    [Input('vehicle-type-dropdown', 'value'),
     Input('year-dropdown', 'value')]
)
def update_graph(vehicle_type, selected_year):
    # Add your logic to generate a plot based on the selected vehicle type and year
    # For now, let's create a simple scatter plot
    filtered_data = your_dataframe[(your_dataframe['Vehicle_Type'] == vehicle_type) & (your_dataframe['Year'] == selected_year)]
    figure = {
        'data': [
            {'x': filtered_data['Date'], 'y': filtered_data['Automobile_Sales'], 'type': 'scatter', 'mode': 'lines+markers'}
        ],
        'layout': {
            'title': f'Automobile Sales for {vehicle_type} in {selected_year}',
            'xaxis': {'title': 'Date'},
            'yaxis': {'title': 'Sales'}
        }
    }
    return figure

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Task 2

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Sample DataFrame
# Replace this with your actual DataFrame and column names
# For example:
your_dataframe = pd.read_csv('D:\\Course\\Data science\\IBM\\historical_automobile_sales.csv')

# Assuming 'Date' and 'Year' are the columns you want to use for dropdowns
report_types = your_dataframe['Vehicle_Type'].unique()
years = your_dataframe['Year'].unique()

# Recession periods
recession_periods = {
    'Yearly Statistics': years,
    'Recession Period Statistics': [1980, 1981, 1982, 1991, 2000, 2001, 2007, 2008, 2009, 2020]
}

app.layout = html.Div([
    html.H1("Automobile Sales Statistics Dashboard", style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    html.Div([
        html.Label("Select Report Type"),
        dcc.Dropdown(
            id='dropdown-statistics',
            options=[
                {'label': 'Yearly Statistics', 'value': 'Yearly Statistics'},
                {'label': 'Recession Period Statistics', 'value': 'Recession Period Statistics'}
            ],
            placeholder='Select a report type',
            value='Select Statistics',
            style={'width': '80%', 'padding': '3px', 'font-size': '20px', 'text-align-last': 'center'}
        ),
    ], style={'margin-bottom': '20px'}),

    html.Div([
        html.Label("Select Year"),
        dcc.Dropdown(
            id='select-year',
            options=[],
            placeholder='Select a year',
            style={'width': '80%', 'padding': '3px', 'font-size': '20px', 'text-align-last': 'center'}
        ),
    ], style={'margin-bottom': '20px'}),

    html.Div([
        html.H2("Graphs Layout"),
        dcc.Graph(id='sample-graph')  # Include a simple graph component for testing
    ]),

])

@app.callback(
    Output('select-year', 'options'),
    [Input('dropdown-statistics', 'value')]
)
def update_year_dropdown(report_type):
    if report_type:
        available_years = recession_periods.get(report_type, [])
        print(f"Available years for {report_type}: {available_years}")
        return [{'label': year, 'value': year} for year in available_years]
    return []

@app.callback(
    Output('select-year', 'disabled'),
    [Input('dropdown-statistics', 'value')]
)
def update_year_dropdown_disable(report_type):
    return not bool(report_type)

@app.callback(
    Output('sample-graph', 'figure'),
    [Input('dropdown-statistics', 'value'),
     Input('select-year', 'value')]
)
@app.callback(
    Output('sample-graph', 'figure'),
    [Input('dropdown-statistics', 'value'),
     Input('select-year', 'value')]
)
def update_graph(report_type, selected_year):
    if report_type and selected_year:
        print(f"Unique Years in Dataset: {your_dataframe['Year'].unique()}")
        print(f"Unique Vehicle Types in Dataset: {your_dataframe['Vehicle_Type'].unique()}")

        filtered_data = your_dataframe[(your_dataframe['Vehicle_Type'] == report_type) & (your_dataframe['Year'] == selected_year)]
        print(f"Filtered data for {report_type} in {selected_year}:")
        print(filtered_data)
        
        if not filtered_data.empty:
            figure = {
                'data': [
                    {'x': filtered_data['Date'], 'y': filtered_data['Automobile_Sales'], 'type': 'scatter', 'mode': 'lines+markers'}
                ],
                'layout': {
                    'title': f'Automobile Sales for {report_type} in {selected_year}',
                    'xaxis': {'title': 'Date'},
                    'yaxis': {'title': 'Sales'}
                }
            }
            return figure
        else:
            print(f"No data available for {report_type} in {selected_year}.")
    return {'data': [], 'layout': {}}

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Add these lines in the update_graph callback function
print(f"Unique Vehicle Types: {your_dataframe['Vehicle_Type'].unique()}")
print(f"Unique Years: {your_dataframe['Year'].unique()}")
# Out:
# Unique Vehicle Types: ['Supperminicar' 'Mediumfamilycar' 'Smallfamiliycar' 'Sports'
#  'Executivecar']
# Unique Years: [1980 1981 1982 1983 1990 1991 1992 2000 2001 2002 2008 2009 2020 1984
#  1985 1986 1987 1988 1989 1993 1994 1995 1996 1997 1998 1999 2003 2004
#  2005 2006 2007 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2021
#  2022 2023]

# %% [markdown]
# ### TASK 3

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Sample DataFrame
# Replace this with your actual DataFrame and column names
# For example:
your_dataframe = pd.read_csv('D:\\Course\\Data science\\IBM\\historical_automobile_sales.csv')

# Assuming 'Date' and 'Year' are the columns you want to use for dropdowns
report_types = your_dataframe['Vehicle_Type'].unique()
years = your_dataframe['Year'].unique()

# Recession periods
recession_periods = {
    'Yearly Statistics': years,
    'Recession Period Statistics': [1980, 1981, 1982, 1991, 2000, 2001, 2007, 2008, 2009, 2020]
}

app.layout = html.Div([
    html.H1("Automobile Sales Statistics Dashboard", style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    html.Div([
        html.Label("Select Report Type"),
        dcc.Dropdown(
            id='dropdown-statistics',
            options=[
                {'label': 'Yearly Statistics', 'value': 'Yearly Statistics'},
                {'label': 'Recession Period Statistics', 'value': 'Recession Period Statistics'}
            ],
            placeholder='Select a report type',
            value='Select Statistics',
            style={'width': '80%', 'padding': '3px', 'font-size': '20px', 'text-align-last': 'center'}
        ),
    ], style={'margin-bottom': '20px'}),

    html.Div([
        html.Label("Select Year"),
        dcc.Dropdown(
            id='select-year',
            options=[],
            placeholder='Select a year',
            style={'width': '80%', 'padding': '3px', 'font-size': '20px', 'text-align-last': 'center'}
        ),
    ], style={'margin-bottom': '20px'}),

    html.Div([
        html.H2("Graphs Layout"),
        dcc.Graph(id='sample-graph')  # Include a simple graph component for testing
    ]),

    # Added division for output display
    html.Div([
        html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
    ])
])

@app.callback(
    [Output('select-year', 'options'),
     Output('select-year', 'disabled')],
    [Input('dropdown-statistics', 'value')]
)
def update_year_dropdown(report_type):
    if report_type:
        available_years = recession_periods.get(report_type, [])
        return [{'label': year, 'value': year} for year in available_years], not bool(report_type)
    return [], True

@app.callback(
    Output('sample-graph', 'figure'),
    [Input('dropdown-statistics', 'value'),
     Input('select-year', 'value')]
)
def update_graph(report_type, selected_year):
    if report_type and selected_year:
        print(f"Unique Years: {your_dataframe['Year'].unique()}")
        print(f"Unique Vehicle Types: {your_dataframe['Vehicle_Type'].unique()}")
        filtered_data = your_dataframe[(your_dataframe['Vehicle_Type'] == report_type) & (your_dataframe['Year'] == selected_year)]
        print(f"Filtered data for {report_type} in {selected_year}:")
        print(filtered_data)

        if not filtered_data.empty:
            figure = {
                'data': [
                    {'x': filtered_data['Date'], 'y': filtered_data['Automobile_Sales'], 'type': 'scatter', 'mode': 'lines+markers'}
                ],
                'layout': {
                    'title': f'Automobile Sales for {report_type} in {selected_year}',
                    'xaxis': {'title': 'Date'},
                    'yaxis': {'title': 'Sales'}
                }
            }
            return figure
        else:
            print(f"No data available for {report_type} in {selected_year}.")
    return {'data': [], 'layout': {}}

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
